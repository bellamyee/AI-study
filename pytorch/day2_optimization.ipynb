# %% [markdown]
# # Generalization
# #### How well the learned model will behave on unseen data(Trainning Error와 test error의 차이)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Cross-validation
# #### k-fold validation : k개로 나누어서 1~k-1 번째 partition을 제외하며 학습, test
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bias and Variance
# ### Variance : 입력에 대해 출력이 일관적으로 나오는 것
# ### Bias : 평균적으로 봤을 때 True Target에 접근 되는것
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Bagging vs Boosting
# ### Bagging : 여러개의 모델을 bootstraping. ex) 앙상블 기법
# ### Boosting : 학습하기 어려운 특정 trainning sample에 대해서 또 다른 모델을 만듬(결과적으로 한개의 모델)
# ![image.png](attachment:image.png)

# %% [markdown]
# # Gradient Descent Methods
# ### SGD : 한번에 하나씩 사용 순차적 학습
# ### Mini-batch GD : 한번에 한 batch
# ### batch GD : 한번에 다 사용

# %% [markdown]
# ### 배치사이즈를 작게 사용하는게 일반적으로 좋다
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ### Train 과 Test 차이를 줄이기 위해!!

# %% [markdown]
# # Optimizing 방법
# ### GD : learning rate를 적당히 잡는 것이 어려움
# ![image.png](attachment:image.png)
# ### Momentum : 이전 step(batch)에서 나왔던 gradient 정보를 활용하자. 한번 흘러간 gradient를 계속 유지
# ![image-2.png](attachment:image-2.png)
# ### Nesterov Accelerated Gradient : Momentum과 유사. 이전 정보를 이용해 한번 가보고, 그 지점에서 gradient 계산. local minima를 넘어갔더라도 momentum 방향으로 가는 momentum의 단점을 보완
# ![image-3.png](attachment:image-3.png)
# ###
